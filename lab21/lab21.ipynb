# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

# %%
x, y = make_regression(n_samples=15000, n_features=4, noise=90, random_state=42)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.score(x_test, y_test))
# Out:
# 0.7337811992811193

# %% [markdown]
# Первый полученый результат был: 0.8158127017462382 (число признаков: 3, noise = 50, число семплов = 500)
# Далее, я решил немного поиграться с параметрами.
#
# Если в make_regression() параметр noise=1000, то точность получается 0.006358895175563095 😂
# Однако, если увеличить количество признаков, то точность возрастет -> при 10 признаках точность = 0.021902266890141964
#
# Самый лучший результат был получен при следующих параметрах: n_samples=1000, n_features=4, noise=10, random_state=42; точнсть составила добрые 0.9918983133386269 😎👍🏻
#
# Если дальше увеличивать параметр noise, то модель перестает быть пригодной при noise > 70,
# однако, если значительно увеличить размер выборки при noise > 70, точность увеличится.
#
# Можно сделать вывод: чем выше значение параметра noise, тем болший размер выборки потребуется задать, чтобы модель получилась пригодной.

# %%
from sklearn.datasets import make_classification
x, y = make_classification(n_samples=1500, n_features=3, class_sep=0.3, random_state=42, n_redundant=0, n_repeated=0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.6422222222222222

# %% [markdown]
# При параметрах n_samples=1000, n_features=3, class_sep=1, random_state=42, n_redundant=0, n_repeated=0 точность получается 0.8633333333333333
#
# Если начать уменьшать параметр class_sep, точность будет уменьшаться, при этом не поможет увеличение числа выборки.
